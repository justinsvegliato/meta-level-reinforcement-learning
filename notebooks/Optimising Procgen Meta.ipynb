# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set()

# %%
from rlts.runners.eval_runner import EvalRunner
from rlts.meta.meta_policies.a_star_policy import AStarPolicy
from rlts.meta.meta_policies.random_policy import create_random_search_policy, create_random_search_policy_no_terminate
from rlts.meta.meta_policies.terminator_policy import TerminatorPolicy
from rlts.train.procgen_meta import create_batched_procgen_meta_envs, load_pretrained_q_network
from rlts.train.procgen_meta import reset_object_level_metrics, get_object_level_metrics


def create_test_batched_meta_envs(env_multithreading: bool = False,
                                  patch_terminates: bool = True,
                                  patch_expansions: bool = True,
                                  create_intermediate_search_policies: bool = False,
                                  compute_meta_rewards: bool = False):
    args = {
        'pretrained_runs_folder': 'runs',
        'pretrained_run': 'run-16823527592836354',
        'pretrained_percentile': 0.75,
        'expand_all_actions': True,
        'collect_steps_per_iteration': 16,
        'finish_on_terminate': True,
        'max_tree_size': 64,
    }

    object_config = load_pretrained_q_network(
        folder=args['pretrained_runs_folder'],
        run=args['pretrained_run'],
        percentile=args.get('pretrained_percentile', 0.5),
        verbose=False
    )

    batched_meta_env = create_batched_procgen_meta_envs(n_envs=64,
                                                        object_config=object_config,
                                                        env_multithreading=env_multithreading,
                                                        patch_terminates=patch_terminates,
                                                        patch_expansions=patch_expansions,
                                                        compute_meta_rewards=compute_meta_rewards,
                                                        create_intermediate_search_policies=create_intermediate_search_policies,
                                                        **args)
    return batched_meta_env

# %%
from cProfile import Profile
from time import time


def profile_random_steps(batched_meta_env, n_step: int = 50) -> Profile:
    batched_meta_env.reset()

    policy = create_random_search_policy_no_terminate(batched_meta_env)
    ts = batched_meta_env.current_time_step()
    policy_step = policy.action(ts)

    profile = Profile()
    profile.enable()

    for _ in range(n_step):
        ts = batched_meta_env.step(policy_step.action)
        policy_step = policy.action(ts)

    profile.disable()

    return profile


def time_random_steps(batched_meta_env, n_step: int = 50) -> Profile:
    batched_meta_env.reset()

    policy = create_random_search_policy_no_terminate(batched_meta_env)
    ts = batched_meta_env.current_time_step()
    policy_step = policy.action(ts)

    start_time = time()
    for _ in range(n_step):
        ts = batched_meta_env.step(policy_step.action)
        policy_step = policy.action(ts)
    time_taken = time() - start_time

    return time_taken

# %%
results = []

for _ in range(5):
    batched_meta_env = create_test_batched_meta_envs(
        env_multithreading=False,
        patch_terminates=True,
        patch_expansions=True,
        compute_meta_rewards=False,
        create_intermediate_search_policies=False,
    )
    time_taken = time_random_steps(batched_meta_env)
    results.append({
        'env_multithreading': False,
        'create_intermediate_search_policies': True,
        'patch_terminates': True,
        'patch_expansions': True,
        'compute_meta_rewards': False,
    })

# %%
import pstats

# patching terminates and expansions
batched_meta_env = create_test_batched_meta_envs()
profile_patch_all, time_taken = profile_random_steps(batched_meta_env)
pstats.Stats(profile_patch_all).sort_stats('cumulative').print_stats(10)
# Out:
#          8214126 function calls (8128271 primitive calls) in 30.808 seconds
#
#    Ordered by: cumulative time
#    List reduced from 807 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    140/50    0.003    0.000   30.442    0.609 /usr/local/lib/python3.8/dist-packages/tf_agents/environments/py_environment.py:198(step)
#        45    0.014    0.000   27.743    0.617 /tf/rlts/procgen/batched_procgen_meta_env.py:245(_step)
#        45    0.050    0.001   19.725    0.438 /tf/rlts/procgen/batched_procgen_meta_env.py:219(handle_requests)
#     49472    9.413    0.000    9.426    0.000 /usr/local/lib/python3.8/dist-packages/gym3/libenv.py:383(call_c_func)
# 33640/18845    0.054    0.000    7.845    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py:138(error_handler)
# 30665/18845    0.126    0.000    7.736    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1162(op_dispatch_handler)
#       365    0.010    0.000    7.318    0.020 /tf/rlts/procgen/procgen_state.py:31(call)
#       365    0.010    0.000    6.819    0.019 /usr/local/lib/python3.8/dist-packages/tf_agents/networks/network.py:349(__call__)
#      2605    0.026    0.000    6.192    0.002 /usr/local/lib/python3.8/dist-packages/procgen/env.py:149(set_state)
#     16585    0.015    0.000    5.473    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/profiler/trace.py:178(wrapped)

# %%
import pstats

# patching terminates and expansions
batched_meta_env = create_test_batched_meta_envs(env_multithreading=True)
profile_patch_all = profile_random_steps(batched_meta_env)
pstats.Stats(profile_patch_all).sort_stats('cumulative').print_stats(10)
# Out:
#          2419413 function calls (2376317 primitive calls) in 42.423 seconds
#
#    Ordered by: cumulative time
#    List reduced from 739 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    140/50    0.003    0.000   41.774    0.835 /usr/local/lib/python3.8/dist-packages/tf_agents/environments/py_environment.py:198(step)
#        45    0.012    0.000   39.508    0.878 /tf/rlts/procgen/batched_procgen_meta_env.py:245(_step)
#        45    0.073    0.002   19.974    0.444 /tf/rlts/procgen/batched_procgen_meta_env.py:219(handle_requests)
#        90    0.001    0.000   18.055    0.201 /usr/lib/python3.8/multiprocessing/pool.py:764(get)
#        90    0.001    0.000   18.054    0.201 /usr/lib/python3.8/multiprocessing/pool.py:761(wait)
#        90    0.001    0.000   18.054    0.201 /usr/lib/python3.8/threading.py:540(wait)
#        90    0.002    0.000   18.052    0.201 /usr/lib/python3.8/threading.py:270(wait)
#       363   18.050    0.050   18.050    0.050 {method 'acquire' of '_thread.lock' objects}
#        45    0.002    0.000   13.471    0.299 /tf/rlts/procgen/batched_procgen_meta_env.py:260(create_time_step)
#        45    0.000    0.000   13.009    0.289 /usr/lib/python3.8/multiprocessing/pool.py:359(map)

# %%
import pstats

# patching terminates and expansions
batched_meta_env = create_test_batched_meta_envs(create_intermediate_search_policies=True)
profile_patch_all = profile_random_steps(batched_meta_env)
pstats.Stats(profile_patch_all).sort_stats('cumulative').print_stats(10)
# Out:
#          8206282 function calls (8120427 primitive calls) in 33.835 seconds
#
#    Ordered by: cumulative time
#    List reduced from 763 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    140/50    0.003    0.000   33.319    0.666 /usr/local/lib/python3.8/dist-packages/tf_agents/environments/py_environment.py:198(step)
#        45    0.019    0.000   30.544    0.679 /tf/rlts/procgen/batched_procgen_meta_env.py:245(_step)
#        45    0.059    0.001   19.814    0.440 /tf/rlts/procgen/batched_procgen_meta_env.py:219(handle_requests)
#     49472    9.719    0.000    9.736    0.000 /usr/local/lib/python3.8/dist-packages/gym3/libenv.py:383(call_c_func)
# 33640/18845    0.064    0.000    8.138    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py:138(error_handler)
# 30665/18845    0.151    0.000    8.010    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1162(op_dispatch_handler)
#       365    0.012    0.000    7.381    0.020 /tf/rlts/procgen/procgen_state.py:31(call)
#       365    0.012    0.000    6.828    0.019 /usr/local/lib/python3.8/dist-packages/tf_agents/networks/network.py:349(__call__)
#      2605    0.037    0.000    6.444    0.002 /usr/local/lib/python3.8/dist-packages/procgen/env.py:149(set_state)
#        45    0.001    0.000    5.750    0.128 /tf/rlts/procgen/batched_procgen_meta_env.py:260(create_time_step)

# %%
import pstats

# patching terminates and expansions
batched_meta_env = create_test_batched_meta_envs(compute_meta_rewards=True)
profile_patch_all = profile_random_steps(batched_meta_env)
pstats.Stats(profile_patch_all).sort_stats('cumulative').print_stats(10)
# Out:
#          24725931 function calls (23129409 primitive calls) in 70.125 seconds
#
#    Ordered by: cumulative time
#    List reduced from 771 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    150/50    0.004    0.000   68.735    1.375 /usr/local/lib/python3.8/dist-packages/tf_agents/environments/py_environment.py:198(step)
#        50    0.044    0.001   68.724    1.374 /tf/rlts/procgen/batched_procgen_meta_env.py:245(_step)
#        50    0.156    0.003   33.895    0.678 /tf/rlts/procgen/batched_procgen_meta_env.py:219(handle_requests)
#        50    0.003    0.000   25.533    0.511 /tf/rlts/procgen/batched_procgen_meta_env.py:260(create_time_step)
#        50    0.012    0.000   24.994    0.500 /tf/rlts/procgen/batched_procgen_meta_env.py:265(<listcomp>)
#      3200    0.057    0.000   24.981    0.008 /tf/rlts/procgen/batched_procgen_meta_env.py:271(_create_time_step)
#      3200    0.067    0.000   24.271    0.008 /tf/rlts/meta/meta_env.py:660(observe)
# 28008/11929    0.100    0.000   15.620    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py:138(error_handler)
# 25029/11929    0.258    0.000   15.420    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1162(op_dispatch_handler)
#      3200    0.026    0.000   14.489    0.005 /tf/rlts/meta/meta_env.py:214(<lambda>)

# %%
import pstats

# patching terminates and expansions
batched_meta_env = create_test_batched_meta_envs()
profile_patch_all = profile_random_steps(batched_meta_env)
pstats.Stats(profile_patch_all).sort_stats('cumulative').print_stats(10)
# Out:
#          24486434 function calls (22970102 primitive calls) in 69.030 seconds
#
#    Ordered by: cumulative time
#    List reduced from 789 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    140/50    0.013    0.000   67.864    1.357 /usr/local/lib/python3.8/dist-packages/tf_agents/environments/py_environment.py:198(step)
#        45    0.035    0.001   64.978    1.444 /tf/rlts/procgen/batched_procgen_meta_env.py:245(_step)
#        45    0.145    0.003   32.710    0.727 /tf/rlts/procgen/batched_procgen_meta_env.py:219(handle_requests)
#        45    0.004    0.000   25.396    0.564 /tf/rlts/procgen/batched_procgen_meta_env.py:260(create_time_step)
#        45    0.012    0.000   24.854    0.552 /tf/rlts/procgen/batched_procgen_meta_env.py:265(<listcomp>)
#      2880    0.054    0.000   24.842    0.009 /tf/rlts/procgen/batched_procgen_meta_env.py:271(_create_time_step)
#      2880    0.068    0.000   24.133    0.008 /tf/rlts/meta/meta_env.py:660(observe)
#      3200    0.027    0.000   14.909    0.005 /tf/rlts/meta/meta_env.py:214(<lambda>)
#      3200    0.066    0.000   14.882    0.005 /tf/rlts/meta/tree_policy.py:124(__init__)
# 33640/18845    0.101    0.000   14.424    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py:138(error_handler)

# %%
import pstats

# patching just expansions
batched_meta_env = create_test_batched_meta_envs(patch_terminates=False)
profile_just_expansions = profile_random_steps(batched_meta_env)
pstats.Stats(profile_just_expansions).sort_stats('cumulative').print_stats(10)
# Out:
#          25350015 function calls (23842361 primitive calls) in 73.344 seconds
#
#    Ordered by: cumulative time
#    List reduced from 783 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    130/50    0.005    0.000   72.438    1.449 /usr/local/lib/python3.8/dist-packages/tf_agents/environments/py_environment.py:198(step)
#        45    0.039    0.001   68.244    1.517 /tf/rlts/procgen/batched_procgen_meta_env.py:245(_step)
#        40    0.075    0.002   28.342    0.709 /tf/rlts/procgen/batched_procgen_meta_env.py:219(handle_requests)
#        45    0.002    0.000   24.657    0.548 /tf/rlts/procgen/batched_procgen_meta_env.py:260(create_time_step)
#        45    0.012    0.000   24.266    0.539 /tf/rlts/procgen/batched_procgen_meta_env.py:265(<listcomp>)
#      2880    0.062    0.000   24.253    0.008 /tf/rlts/procgen/batched_procgen_meta_env.py:271(_create_time_step)
#      2880    0.070    0.000   23.509    0.008 /tf/rlts/meta/meta_env.py:660(observe)
# 41830/26720    0.277    0.000   17.378    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py:138(error_handler)
# 38540/26720    0.393    0.000   16.834    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1162(op_dispatch_handler)
#       680    0.036    0.000   16.802    0.025 /tf/rlts/procgen/procgen_state.py:31(call)

# %%
import pstats

# patching just terminates
batched_meta_env = create_test_batched_meta_envs(patch_expansions=False)
profile_just_terminates = profile_random_steps(batched_meta_env)
pstats.Stats(profile_just_terminates).sort_stats('cumulative').print_stats(50)
# Out:
#          101461480 function calls (99273187 primitive calls) in 215.790 seconds
#
#    Ordered by: cumulative time
#    List reduced from 783 to 50 due to restriction <50>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     60/50    0.002    0.000  215.333    4.307 /usr/local/lib/python3.8/dist-packages/tf_agents/environments/py_environment.py:198(step)
#        45    0.031    0.001  211.999    4.711 /tf/rlts/procgen/batched_procgen_meta_env.py:245(_step)
#      2880    0.015    0.000  192.749    0.067 /tf/rlts/procgen/batched_procgen_meta_env.py:208(collect_expansion_requests)
#      2880    0.090    0.000  192.715    0.067 /tf/rlts/meta/meta_env.py:617(act)
#      2560    0.021    0.000  191.851    0.075 /tf/rlts/meta/meta_env.py:600(perform_computational_action)
#      2560    0.082    0.000  191.477    0.075 /tf/rlts/meta/search_tree.py:520(expand_all)
#     20480    0.143    0.000  190.806    0.009 /tf/rlts/meta/search_tree.py:534(expand_action)
#     20480    0.113    0.000  189.900    0.009 /tf/rlts/meta/search_tree.py:284(expand_node)
#     20480    0.331    0.000  189.733    0.009 /tf/rlts/meta/search_tree.py:266(create_child)
#     20800    0.073    0.000  175.064    0.008 /tf/rlts/procgen/procgen_state.py:64(extract_state)
#     21120    4.011    0.000  174.991    0.008 /tf/rlts/procgen/procgen_state.py:87(__init__)
#     20805    0.626    0.000  162.688    0.008 /tf/rlts/procgen/procgen_state.py:31(call)
#     20805    0.653    0.000  128.119    0.006 /usr/local/lib/python3.8/dist-packages/tf_agents/networks/network.py:349(__call__)
# 145635/41610    0.951    0.000  125.377    0.003 /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:59(error_handler)
# 145635/41610    5.452    0.000  124.988    0.003 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:1000(__call__)
# 145635/41610    0.564    0.000  104.049    0.003 /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:92(error_handler)
#     20805    0.865    0.000   95.583    0.005 /usr/local/lib/python3.8/dist-packages/tf_agents/networks/encoding_network.py:300(call)
# 565080/529845    1.222    0.000   86.066    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py:138(error_handler)
# 541665/529845    3.039    0.000   83.218    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1162(op_dispatch_handler)
#    425170   53.014    0.000   53.014    0.000 {built-in method tensorflow.python._pywrap_tfe.TFE_Py_FastPathExecute}
#     62415    1.064    0.000   37.441    0.001 /usr/local/lib/python3.8/dist-packages/keras/layers/convolutional/base_conv.py:279(call)
#     62415    0.384    0.000   20.264    0.000 /usr/local/lib/python3.8/dist-packages/keras/layers/convolutional/base_conv.py:254(convolution_op)
#     62415    0.114    0.000   19.201    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py:1171(convolution_v2)
#     62415    1.491    0.000   19.087    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py:1197(convolution_internal)
#    241425    0.330    0.000   19.016    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/profiler/trace.py:178(wrapped)
#    241425    1.015    0.000   18.686    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1574(convert_to_tensor)
#     92360    0.111    0.000   18.314    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py:171(constant)
#     92360    0.273    0.000   18.203    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py:272(_constant_impl)
#     41610    0.759    0.000   17.891    0.000 /usr/local/lib/python3.8/dist-packages/keras/layers/core/dense.py:179(call)
#    208350    1.190    0.000   17.751    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:809(map_structure)
#     92360    0.149    0.000   17.689    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py:303(_constant_eager_impl)
#     92360   17.332    0.000   17.540    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py:75(convert_to_eager_tensor)
#    145635    0.314    0.000   17.472    0.000 /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:77(inject_argument_info_in_traceback)
#    145635    1.171    0.000   17.158    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/tf_decorator.py:115(make_decorator)
#     62415    0.213    0.000   16.489    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py:2773(_conv2d_expanded_batch)
#     62415    0.215    0.000   16.218    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py:1035(conv2d)
#    166890    0.161    0.000   16.134    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1432(convert_to_tensor_v2_with_dispatch)
#        45    0.001    0.000   16.012    0.356 /tf/rlts/procgen/batched_procgen_meta_env.py:260(create_time_step)
#    166890    0.294    0.000   15.973    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1500(convert_to_tensor_v2)
#        45    0.005    0.000   15.692    0.349 /tf/rlts/procgen/batched_procgen_meta_env.py:265(<listcomp>)
#      2880    0.024    0.000   15.687    0.005 /tf/rlts/procgen/batched_procgen_meta_env.py:271(_create_time_step)
#     43840    0.116    0.000   15.484    0.000 /usr/local/lib/python3.8/dist-packages/gym3/wrapper.py:28(callmethod)
# 665760/332880    2.532    0.000   15.441    0.000 /usr/lib/python3.8/inspect.py:2218(_signature_from_callable)
#     43840    0.089    0.000   15.368    0.000 /usr/local/lib/python3.8/dist-packages/gym3/env.py:68(callmethod)
#      2880    0.027    0.000   15.321    0.005 /tf/rlts/meta/meta_env.py:660(observe)
#    104025    0.714    0.000   15.026    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py:3510(bias_add)
#    208350    0.300    0.000   14.796    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:917(<listcomp>)
#    291270    0.282    0.000   14.073    0.000 /usr/lib/python3.8/inspect.py:3103(signature)
#     41860    0.076    0.000   14.021    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py:46(_default_conversion_function)
#    291270    0.356    0.000   13.791    0.000 /usr/lib/python3.8/inspect.py:2851(from_callable)

# %%
from rlts.procgen.procgen_state import ProcgenProcessing

# %%
time_step = batched_meta_env.object_envs.reset()

profile2 = Profile()
profile2.enable()

for _ in range(10):
    _, q_vals = ProcgenProcessing.call(time_step.observation)
    time_step = batched_meta_env.object_envs.step(q_vals.argmax(axis=-1))

profile2.disable()

# %%
pstats.Stats(profile2).sort_stats('cumulative').print_stats(50)
# Out:
#          36779 function calls (36439 primitive calls) in 3.467 seconds
#
#    Ordered by: cumulative time
#    List reduced from 316 to 50 due to restriction <50>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    3.467    1.733 /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3424(run_code)
#         2    0.000    0.000    3.467    1.733 {built-in method builtins.exec}
#         1    0.005    0.005    3.467    3.467 /tmp/ipykernel_13/90310075.py:6(<module>)
#        10    0.001    0.000    2.615    0.262 /tf/rlts/procgen/procgen_state.py:31(call)
#        10    0.013    0.001    2.580    0.258 /usr/local/lib/python3.8/dist-packages/tf_agents/networks/network.py:349(__call__)
#   260/250    0.001    0.000    2.523    0.010 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py:138(error_handler)
#       250    0.003    0.000    2.521    0.010 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1162(op_dispatch_handler)
#       110    0.000    0.000    2.473    0.022 /usr/local/lib/python3.8/dist-packages/tensorflow/python/profiler/trace.py:178(wrapped)
#       110    0.001    0.000    2.473    0.022 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1574(convert_to_tensor)
#        80    0.000    0.000    2.472    0.031 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1432(convert_to_tensor_v2_with_dispatch)
#        80    0.000    0.000    2.471    0.031 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1500(convert_to_tensor_v2)
#        40    0.000    0.000    2.470    0.062 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py:171(constant)
#        40    0.000    0.000    2.470    0.062 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py:272(_constant_impl)
#        40    0.000    0.000    2.469    0.062 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py:303(_constant_eager_impl)
#        40    2.469    0.062    2.469    0.062 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py:75(convert_to_eager_tensor)
#        20    0.000    0.000    2.468    0.123 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py:46(_default_conversion_function)
#     70/20    0.001    0.000    1.398    0.070 /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:59(error_handler)
#     70/20    0.005    0.000    1.397    0.070 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:1000(__call__)
#       100    0.001    0.000    1.315    0.013 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:809(map_structure)
#       100    0.000    0.000    1.313    0.013 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:917(<listcomp>)
#        70    0.000    0.000    1.307    0.019 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:3723(_convert_numpy_or_python_types)
#        20    0.001    0.000    1.174    0.059 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:345(assert_matching_dtypes_and_inner_shapes)
#        20    0.000    0.000    1.168    0.058 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:381(<listcomp>)
#        10    0.000    0.000    1.168    0.117 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:376(_convert)
#     20/10    0.000    0.000    0.846    0.085 /usr/local/lib/python3.8/dist-packages/tf_agents/environments/py_environment.py:198(step)
#        10    0.000    0.000    0.846    0.085 /tf/rlts/utils/env_wrappers.py:50(_step)
#        10    0.186    0.019    0.450    0.045 /tf/rlts/utils/procgen_gym3_wrapper.py:105(_step)
#        10    0.395    0.039    0.395    0.039 /tf/rlts/utils/env_wrappers.py:42(preprocess)
#        50    0.001    0.000    0.188    0.004 /usr/local/lib/python3.8/dist-packages/gym3/extract_dict_ob.py:9(observe)
#        50    0.000    0.000    0.188    0.004 /usr/local/lib/python3.8/dist-packages/gym3/wrapper.py:19(observe)
#        50    0.086    0.002    0.187    0.004 /usr/local/lib/python3.8/dist-packages/gym3/libenv.py:344(observe)
#       170    0.104    0.001    0.104    0.001 {method 'copy' of 'numpy.ndarray' objects}
#        50    0.001    0.000    0.097    0.002 /usr/local/lib/python3.8/dist-packages/gym3/libenv.py:281(_maybe_copy_dict)
#     70/20    0.000    0.000    0.077    0.004 /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:92(error_handler)
#        10    0.001    0.000    0.070    0.007 /usr/local/lib/python3.8/dist-packages/tf_agents/networks/encoding_network.py:300(call)
#        40    0.000    0.000    0.069    0.002 /usr/local/lib/python3.8/dist-packages/gym3/wrapper.py:25(act)
#        40    0.001    0.000    0.068    0.002 /usr/local/lib/python3.8/dist-packages/procgen/env.py:197(act)
#        40    0.067    0.002    0.067    0.002 /usr/local/lib/python3.8/dist-packages/gym3/libenv.py:352(act)
#       200    0.039    0.000    0.039    0.000 {built-in method tensorflow.python._pywrap_tfe.TFE_Py_FastPathExecute}
#        30    0.001    0.000    0.026    0.001 /usr/local/lib/python3.8/dist-packages/keras/layers/convolutional/base_conv.py:279(call)
#        30    0.000    0.000    0.016    0.001 /usr/local/lib/python3.8/dist-packages/keras/layers/convolutional/base_conv.py:254(convolution_op)
#        30    0.000    0.000    0.015    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py:1171(convolution_v2)
#        30    0.001    0.000    0.015    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py:1197(convolution_internal)
#        20    0.000    0.000    0.013    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1136(numpy)
#        30    0.000    0.000    0.013    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py:2773(_conv2d_expanded_batch)
#        70    0.000    0.000    0.013    0.000 /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:77(inject_argument_info_in_traceback)
#        30    0.000    0.000    0.013    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py:1035(conv2d)
#   320/160    0.002    0.000    0.013    0.000 /usr/lib/python3.8/inspect.py:2218(_signature_from_callable)
#        20    0.001    0.000    0.013    0.001 /usr/local/lib/python3.8/dist-packages/keras/layers/core/dense.py:179(call)
#        70    0.001    0.000    0.012    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/tf_decorator.py:115(make_decorator)

# %%
from mlrl.procgen.procgen_state import ProcgenProcessing, ProcgenState

obs = batched_meta_env.envs[0]._gym_env.tree.root_node.state.observation

# %%
obs.shape
# Out:
# (1, 64, 64, 3)

# %%
# %%timeit

for _ in range(512):
    ProcgenProcessing.call(obs)
# Out:
# 1.49 s ± 27.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
np.concatenate([obs for _ in range(512)], axis=0).shape
# Out:
# (512, 64, 64, 3)

# %%
# %%timeit

ProcgenProcessing.call(np.concatenate([obs for _ in range(512)], axis=0))
# Out:
# 60.6 ms ± 1.42 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
print(f"That's a speed-up of {1.49 / 0.0606:.0f}x")
# Out:
# That's a speed-up of 25x

# %%
from mlrl.procgen.procgen_env import make_vectorised_procgen

# %%
n_expansions = len(ProcgenState.ACTIONS)
n_object_envs = batched_meta_env.batch_size * n_expansions

# %%
object_envs = make_vectorised_procgen(object_config, n_envs=n_object_envs)

# %%
from mlrl.experiments.procgen_meta import make_gym_procgen

object_envs_unbatched = [
    make_gym_procgen(object_config) for _ in range(n_object_envs)
]

# %%
states = [e._gym_env.tree.root_node.state.state[0] for e in batched_meta_env.envs for _ in range(n_expansions)]

# %%
action = 0

# %%
# %%timeit

for e, state in zip(object_envs_unbatched, states):
    e.env.env.set_state([state])
    e.step(action)
# Out:
# 155 ms ± 5.33 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
joint_action = np.array([0] * n_object_envs)

# %%
# %%timeit

object_envs.env.set_state(states)
object_envs.step(joint_action)
# Out:
# 86.9 ms ± 875 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit

for e, state in zip(object_envs_unbatched, states):
    e.env.env.set_state([state])
    o, *_ = e.step(action)
    ProcgenProcessing.call(np.expand_dims(o, 0))
# Out:
# 1.68 s ± 41.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit

for e, state in zip(object_envs_unbatched, states):
    e.env.env.set_state([state])
    e.step(action)

# %%
# %%timeit

object_envs.env.set_state(states)
ts = object_envs.step(joint_action)
ProcgenProcessing.call(ts.observation)
# Out:
# 141 ms ± 2.12 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
print(f"That's a speed-up of {1.68 / 0.141:.0f}x")
# Out:
# That's a speed-up of 12x

# %%
# %%timeit

obs = []
for e, state in zip(object_envs_unbatched, states):
    e.env.env.set_state([state])
    o, *_ = e.step(action)
    obs.append(o)


ProcgenProcessing.call(np.array(obs))
# Out:
# 251 ms ± 8.31 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
print(f"That's a speed-up of {1.68 / 0.251:.0f}x")
# Out:
# That's a speed-up of 7x

# %%
42.312 / 12
# Out:
# 3.526

# %%
64.094 / (64.094 - 42.312 + 3.526)
# Out:
# 2.532558874664138

# %%
from mlrl.meta.meta_env import MetaEnv
from mlrl.meta.search_tree import SearchTreeNode
from mlrl.procgen.procgen_state import ProcgenProcessing, ProcgenState
from mlrl.procgen.procgen_env import make_vectorised_procgen

from typing import List, Tuple, Optional, Dict

from multiprocessing import pool
from multiprocessing import dummy as mp_threads
import numpy as np
import gym

import tensorflow as tf
from tf_agents.environments.gym_wrapper import spec_from_gym_space
from tf_agents.environments.py_environment import PyEnvironment
from tf_agents.trajectories import time_step as ts
from tf_agents.typing import types
from tf_agents.utils import nest_utils


class NodeExpansionRequest:
    
    def __init__(self,
                 node: SearchTreeNode[ProcgenState],
                 child_node: SearchTreeNode[ProcgenState],
                 action: int):
        self.node = node
        self.action = action
        self.child_node = child_node

    def get_state(self) -> bytes:
        return self.node.state.state[0]


class BatchedProcgenMetaEnv(PyEnvironment):

    def __init__(self,
                 meta_envs: List[MetaEnv],
                 max_expansions: int,
                 object_config: dict,
                 spec_dtype_map: Optional[Dict[gym.Space, np.dtype]] = None,
                 simplify_box_bounds: bool = True,
                 discount: types.Float = 0.99,
                 multithreading: bool = True,
                 auto_reset: bool = True):
        super(BatchedProcgenMetaEnv, self).__init__(auto_reset)

        self.meta_envs = meta_envs
        self.n_meta_envs = len(meta_envs)
        self.n_object_envs = max_expansions * len(meta_envs)
        self.object_config = object_config
        self.object_envs = make_vectorised_procgen(object_config,
                                                   n_envs=self.n_object_envs)

        env = meta_envs[0]    
        
        self._observation_spec = spec_from_gym_space(env.observation_space,
                                                     spec_dtype_map,
                                                     simplify_box_bounds,
                                                     'observation')

        self._action_spec = spec_from_gym_space(env.action_space,
                                                spec_dtype_map,
                                                simplify_box_bounds,
                                                'action')

        self.expansion_requests: List[NodeExpansionRequest] = []
        self.discount = discount
        self.multithreading = multithreading
        if multithreading:
            self._pool = mp_threads.Pool(self.n_meta_envs)

    @property
    def batched(self) -> bool:
        return self.n_meta_envs > 1

    @property
    def batch_size(self) -> int:
        return self.n_meta_envs

    def observation_spec(self) -> types.NestedArraySpec:
        return self._observation_spec

    def action_spec(self) -> types.NestedArraySpec:
        return self._action_spec

    def _reset(self):

        time_steps = [
            ts.restart(env.reset()) for env in self.meta_envs
        ]

        return nest_utils.stack_nested_arrays(time_steps)

    def patch_node(self, node: SearchTreeNode[ProcgenState]):

        def patched_create_child(_, object_action, new_node_id) -> SearchTreeNode:
            """
            Patched create_child method that creates a new node in the search tree
            without a populated state. The state variables will be set later
            when the expansion request is fulfilled.
            """
            new_node = SearchTreeNode(
                new_node_id, node, ProcgenState(), object_action,
                0, False, node.discount, node.q_function
            )

            self.expansion_requests.append(NodeExpansionRequest(node, new_node, object_action))

            return new_node

        node.create_child = patched_create_child

    def collect_expansion_requests(self, env: MetaEnv, meta_action: int):

        for node in env.tree.node_list:
            self.patch_node(node)

        env.act(meta_action)

    def handle_requests(self):

        states = self.object_envs.env.get_state()
        for i, request in enumerate(self.expansion_requests):
            states[i] = request.get_state()

        object_action = np.array([0] * self.n_object_envs)
        for i, request in enumerate(self.expansion_requests):
            object_action[i] = request.action

        self.object_envs.env.set_state(states)
        ts = self.object_envs.step(object_action)
        new_states = self.object_envs.env.get_state()

        n_requests = len(self.expansion_requests)
        state_vecs, q_values = ProcgenProcessing.call(ts.observation[:n_requests, ...])

        results = zip(self.expansion_requests,
                      state_vecs,
                      q_values,
                      new_states[:n_requests],
                      ts.observation,
                      ts.reward,
                      ts.is_last())

        for req, state_vec, q_value, new_state, obs, reward, done in results:
            req.child_node.reward = reward
            req.child_node.done = done
            req.child_node.state.set_variables([new_state], state_vec, obs, q_value)

    def _step(self, meta_actions: List[int]) -> Tuple[np.ndarray, np.ndarray, np.ndarray, dict]:
        self.expansion_requests.clear()

        def collect_expansion_requests(i, action):
            self.collect_expansion_requests(i, action)

        if self.multithreading:
            self._pool.starmap(self.collect_expansion_requests,
                               zip(self.meta_envs, meta_actions))
        else:
            for i, action in enumerate(meta_actions):
                self.get_expansion_requests(i, action)

        if self.expansion_requests:
            self.handle_requests()

        if self.multithreading:
            time_steps = self._pool.map(lambda e: self._create_time_step(e), self.meta_envs)
        else:
            time_steps = [
                self._create_time_step(env) for env in self.meta_envs
            ]
        return nest_utils.stack_nested_arrays(time_steps)

    def _create_time_step(self, env: MetaEnv):
        observation, reward, done, _ = env.observe()
        step_type = ts.StepType.LAST if done else ts.StepType.MID

        return ts.TimeStep(step_type=step_type,
                           reward=reward,
                           discount=self.discount,
                           observation=observation)

    def render(self, mode='rgb_array'):
        return np.vstack([env.render(mode=mode) for env in self.meta_envs])

# %%
meta_envs = [e._gym_env for e in batched_meta_env.envs]
batched_procgen_meta = BatchedProcgenMetaEnv(meta_envs, len(ProcgenState.ACTIONS), object_config)

# %%
time_step = batched_procgen_meta.step([1] * 64)

# %%
policy = create_random_search_policy_no_terminate(batched_procgen_meta)

# %%
time_step = batched_procgen_meta.current_time_step()
policy_step = policy.action(time_step)
batched_procgen_meta.step(policy_step.action.numpy());

# %%
# %%timeit

time_step = batched_procgen_meta.current_time_step()
policy_step = policy.action(time_step)
batched_procgen_meta.step(policy_step.action.numpy());
# Out:
# 1.18 s ± 266 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
batched_meta_env = create_batched_procgen_meta_envs(n_envs=64, object_config=object_config, env_multithreading=False, **args)
batched_meta_env.reset();

# %%
# %%timeit

time_step = batched_meta_env.current_time_step()
policy_step = policy.action(time_step)
batched_meta_env.step(policy_step.action.numpy());
# Out:
# 3.7 s ± 1.5 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
3.7 / 1.18
# Out:
# 3.1355932203389836

# %%
from cProfile import Profile

policy = create_random_search_policy_no_terminate(batched_procgen_meta)
batched_procgen_meta.reset()

profile = Profile()
profile.enable()

for _ in range(10):
    time_step = batched_procgen_meta.current_time_step()
    policy_step = policy.action(time_step)
    batched_procgen_meta.step(policy_step.action)

profile.disable()


import pstats

pstats.Stats(profile).sort_stats('cumulative').print_stats()
# Out:
#          237095 function calls (230305 primitive calls) in 16.482 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000   16.482    8.241 /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3361(run_code)
#         2    0.000    0.000   16.482    8.241 {built-in method builtins.exec}
#         1    0.000    0.000   16.482   16.482 /tmp/ipykernel_32976/1631964753.py:9(<cell line: 9>)
#     30/10    0.002    0.000   16.197    1.620 /usr/local/lib/python3.8/dist-packages/tf_agents/environments/py_environment.py:198(step)
#        10    0.002    0.000   16.194    1.619 /tmp/ipykernel_32976/3934244552.py:151(_step)
#        20    0.000    0.000    9.225    0.461 /usr/lib/python3.8/multiprocessing/pool.py:764(get)
#        20    0.000    0.000    9.224    0.461 /usr/lib/python3.8/multiprocessing/pool.py:761(wait)
#        20    0.000    0.000    9.224    0.461 /usr/lib/python3.8/threading.py:540(wait)
#        20    0.001    0.000    9.223    0.461 /usr/lib/python3.8/threading.py:270(wait)
#        80    9.222    0.115    9.222    0.115 {method 'acquire' of '_thread.lock' objects}
#        10    0.042    0.004    6.176    0.618 /tmp/ipykernel_32976/3934244552.py:121(handle_requests)
#        10    0.000    0.000    5.706    0.571 /usr/lib/python3.8/multiprocessing/pool.py:359(map)
#        10    0.000    0.000    4.240    0.424 /usr/lib/python3.8/multiprocessing/pool.py:366(starmap)
#     15360    3.626    0.000    3.666    0.000 /usr/local/lib/python3.8/dist-packages/gym3/libenv.py:383(call_c_func)
#        20    0.133    0.007    2.317    0.116 /usr/local/lib/python3.8/dist-packages/procgen/env.py:140(get_state)
# 3810/1170    0.023    0.000    1.809    0.002 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py:138(error_handler)
# 3790/1170    0.038    0.000    1.792    0.002 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1068(op_dispatch_handler)
#        10    0.035    0.003    1.549    0.155 /usr/local/lib/python3.8/dist-packages/procgen/env.py:149(set_state)
#        10    0.001    0.000    1.136    0.114 /tf/mlrl/procgen/procgen_state.py:27(call)
#        10    0.001    0.000    1.078    0.108 /usr/local/lib/python3.8/dist-packages/tf_agents/networks/network.py:349(__call__)
#      2880    0.011    0.000    0.899    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/profiler/trace.py:178(wrapped)
#      2880    0.068    0.000    0.888    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1572(convert_to_tensor)
#     70/20    0.001    0.000    0.881    0.044 /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:58(error_handler)
#     70/20    0.009    0.000    0.881    0.044 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:893(__call__)
#      3944    0.737    0.000    0.815    0.000 /tf/mlrl/procgen/procgen_state.py:109(set_variables)
#       650    0.037    0.000    0.722    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:914(_slice_helper)
#        20    0.002    0.000    0.722    0.036 /usr/lib/python3.8/multiprocessing/pool.py:468(_map_async)
#       640    0.003    0.000    0.717    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:7273(__next__)
#      2060    0.008    0.000    0.636    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py:170(constant)
#      2060    0.028    0.000    0.628    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py:271(_constant_impl)
#     70/20    0.001    0.000    0.612    0.031 /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:88(error_handler)
#       990    0.602    0.001    0.602    0.001 {built-in method tensorflow.python._pywrap_tfe.TFE_Py_FastPathExecute}
#        10    0.001    0.000    0.601    0.060 /usr/local/lib/python3.8/dist-packages/tf_agents/networks/encoding_network.py:300(call)
#      2060    0.043    0.000    0.585    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py:302(_constant_eager_impl)
#      2060    0.526    0.000    0.541    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py:74(convert_to_eager_tensor)
#        30    0.001    0.000    0.506    0.017 /usr/local/lib/python3.8/dist-packages/keras/layers/convolutional/base_conv.py:241(call)
#        30    0.001    0.000    0.477    0.016 /usr/local/lib/python3.8/dist-packages/keras/layers/convolutional/base_conv.py:217(convolution_op)
#        30    0.000    0.000    0.476    0.016 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py:1140(convolution_v2)
#        30    0.001    0.000    0.476    0.016 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py:1166(convolution_internal)
#        30    0.000    0.000    0.472    0.016 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py:2742(_conv2d_expanded_batch)
#        30    0.000    0.000    0.471    0.016 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py:860(conv2d)
#        70    0.013    0.000    0.462    0.007 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py:46(_default_conversion_function)
#       170    0.001    0.000    0.458    0.003 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1430(convert_to_tensor_v2_with_dispatch)
#       170    0.001    0.000    0.457    0.003 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1498(convert_to_tensor_v2)
#      1950    0.008    0.000    0.408    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:1419(stack)
#        10    0.000    0.000    0.305    0.031 /tf/mlrl/utils/env_wrappers.py:50(_step)
#       130    0.003    0.000    0.292    0.002 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:808(map_structure)
#        10    0.000    0.000    0.285    0.028 /usr/local/lib/python3.8/dist-packages/tf_agents/policies/py_policy.py:140(action)
#        10    0.001    0.000    0.285    0.028 /usr/local/lib/python3.8/dist-packages/tf_agents/policies/random_py_policy.py:112(_action)
#       130    0.001    0.000    0.284    0.002 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:916(<listcomp>)
#        70    0.001    0.000    0.255    0.004 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:3389(_convert_numpy_or_python_types)
#        20    0.002    0.000    0.205    0.010 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:345(assert_matching_dtypes_and_inner_shapes)
#        20    0.000    0.000    0.194    0.010 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:381(<listcomp>)
#        10    0.000    0.000    0.194    0.019 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:376(_convert)
#      1970    0.007    0.000    0.192    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py:340(_constant_tensor_conversion_function)
#        10    0.000    0.000    0.162    0.016 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:1218(sample)
#        10    0.001    0.000    0.159    0.016 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:1203(_call_sample_n)
#        10    0.002    0.000    0.157    0.016 /tf/mlrl/utils/procgen_gym3_wrapper.py:105(_step)
#        10    0.147    0.015    0.147    0.015 /tf/mlrl/utils/env_wrappers.py:42(preprocess)
# 26210/26090    0.100    0.000    0.117    0.000 {built-in method builtins.isinstance}
#        10    0.001    0.000    0.104    0.010 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/categorical.py:234(_sample_n)
#      1970    0.020    0.000    0.088    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:1579(_autopacking_conversion_function)
#      3944    0.078    0.000    0.078    0.000 {built-in method builtins.hash}
#        40    0.000    0.000    0.078    0.002 /usr/local/lib/python3.8/dist-packages/gym3/wrapper.py:25(act)
#        40    0.001    0.000    0.078    0.002 /usr/local/lib/python3.8/dist-packages/procgen/env.py:197(act)
#        40    0.076    0.002    0.076    0.002 /usr/local/lib/python3.8/dist-packages/gym3/libenv.py:352(act)
#        50    0.000    0.000    0.073    0.001 /usr/local/lib/python3.8/dist-packages/gym3/extract_dict_ob.py:9(observe)
#        50    0.000    0.000    0.073    0.001 /usr/local/lib/python3.8/dist-packages/gym3/wrapper.py:19(observe)
#        50    0.020    0.000    0.073    0.001 /usr/local/lib/python3.8/dist-packages/gym3/libenv.py:344(observe)
#   790/740    0.040    0.000    0.071    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#      1970    0.019    0.000    0.069    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:1569(_should_not_autopack)
#        10    0.000    0.000    0.067    0.007 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:969(stack_nested_arrays)
#       650    0.003    0.000    0.060    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:1168(strided_slice)
# 23184/23154    0.059    0.000    0.060    0.000 {built-in method builtins.getattr}
#       650    0.004    0.000    0.057    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_array_ops.py:10522(strided_slice)
#       220    0.054    0.000    0.054    0.000 {method 'copy' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.053    0.005 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:980(<listcomp>)
#        50    0.001    0.000    0.053    0.001 <__array_function__ internals>:177(stack)
#        50    0.001    0.000    0.050    0.001 /usr/local/lib/python3.8/dist-packages/numpy/core/shape_base.py:357(stack)
#        10    0.000    0.000    0.046    0.005 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:985(_batch_shape_tensor)
#        10    0.000    0.000    0.046    0.005 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/batch_shape_lib.py:78(inferred_batch_shape_tensor)
#        10    0.000    0.000    0.046    0.005 <decorator-gen-1171>:1(__init__)
#     20/10    0.000    0.000    0.046    0.005 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:333(wrapped_init)
#        10    0.001    0.000    0.045    0.004 /usr/local/lib/python3.8/dist-packages/tf_agents/distributions/masked.py:34(__init__)
#      3270    0.030    0.000    0.044    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:355(flatten)
#        50    0.000    0.000    0.042    0.001 /usr/local/lib/python3.8/dist-packages/gym3/libenv.py:281(_maybe_copy_dict)
#        20    0.000    0.000    0.042    0.002 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/batch_shape_lib.py:281(map_fn_over_parameters_with_event_ndims)
#        50    0.007    0.000    0.041    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/prefer_static.py:68(wrap)
#        30    0.000    0.000    0.039    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:1353(map_structure_up_to)
#        30    0.001    0.000    0.038    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:1434(map_structure_with_tuple_paths_up_to)
#       830    0.022    0.000    0.038    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:6923(__enter__)
#        70    0.000    0.000    0.037    0.001 <__array_function__ internals>:177(concatenate)
#        30    0.000    0.000    0.035    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:1527(<listcomp>)
#        30    0.000    0.000    0.035    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:1429(<lambda>)
#       850    0.007    0.000    0.035    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:6670(name_scope)
#        10    0.000    0.000    0.033    0.003 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/batch_shape_lib.py:119(get_batch_shape_tensor_part)
#        10    0.000    0.000    0.032    0.003 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/batch_shape_lib.py:175(_truncate_shape_tensor)
#        10    0.003    0.000    0.031    0.003 /tf/mlrl/meta/meta_policies/random_policy.py:21(mask_token_splitter_no_terminate)
#   410/250    0.003    0.000    0.031    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/autotrackable.py:58(__setattr__)
#        80    0.001    0.000    0.030    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1135(numpy)
#        60    0.002    0.000    0.029    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/math_ops.py:936(cast)
#   470/230    0.004    0.000    0.028    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/data_structures.py:132(sticky_attribute_assignment)
#       580    0.006    0.000    0.027    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:765(__init__)
#        80    0.000    0.000    0.027    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1123(_numpy)
#        80    0.026    0.000    0.026    0.000 {method '_numpy_internal' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#       220    0.001    0.000    0.026    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:691(pack_sequence_as)
#       220    0.002    0.000    0.025    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:651(_pack_sequence_as)
#      3880    0.013    0.000    0.024    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py:32(is_traceback_filtering_enabled)
#     13650    0.023    0.000    0.023    0.000 {method 'append' of 'list' objects}
#        50    0.000    0.000    0.023    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:66(reshape)
#       530    0.003    0.000    0.022    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1256(shape)
#       640    0.003    0.000    0.022    0.000 <__array_function__ internals>:177(sum)
#        40    0.000    0.000    0.022    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_math_ops.py:1981(cast)
#        10    0.000    0.000    0.022    0.002 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:2018(_set_sample_static_shape)
#        50    0.001    0.000    0.022    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_array_ops.py:8457(reshape)
#   470/270    0.003    0.000    0.020    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/data_structures.py:94(wrap_or_unwrap)
#      4870    0.020    0.000    0.020    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/context.py:973(executing_eagerly)
#      1380    0.007    0.000    0.020    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:723(as_dimension)
#      2900    0.020    0.000    0.020    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/dtypes.py:175(__eq__)
#      2140    0.011    0.000    0.019    0.000 {built-in method builtins.all}
#        20    0.001    0.000    0.018    0.001 /usr/local/lib/python3.8/dist-packages/keras/layers/core/dense.py:166(call)
#      1070    0.004    0.000    0.018    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:775(<genexpr>)
#        20    0.000    0.000    0.018    0.001 <decorator-gen-793>:1(concat)
#        10    0.000    0.000    0.018    0.002 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/random_ops.py:500(categorical)
#   726/706    0.014    0.000    0.018    0.000 {built-in method builtins.next}
#    220/70    0.003    0.000    0.018    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:611(_packed_nest_with_indices)
#        70    0.001    0.000    0.018    0.000 /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:74(inject_argument_info_in_traceback)
#        10    0.000    0.000    0.018    0.002 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/random_ops.py:530(multinomial_categorical_impl)
#        10    0.002    0.000    0.018    0.002 /tf/mlrl/utils/procgen_gym3_wrapper.py:128(_create_time_step)
#       980    0.003    0.000    0.018    0.000 /usr/lib/python3.8/abc.py:96(__instancecheck__)
#      2050    0.011    0.000    0.017    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py:112(get)
#        70    0.015    0.000    0.017    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/tf_decorator.py:61(make_decorator)
#        10    0.000    0.000    0.017    0.002 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_random_ops.py:24(multinomial)
#        10    0.000    0.000    0.017    0.002 <decorator-gen-937>:1(__init__)
#        10    0.000    0.000    0.017    0.002 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_random_ops.py:89(multinomial_eager_fallback)
#        10    0.000    0.000    0.017    0.002 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/data_structures.py:796(__init__)
#        10    0.000    0.000    0.016    0.002 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/categorical.py:152(__init__)
#      3060    0.011    0.000    0.016    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1129(dtype)
#        70    0.003    0.000    0.016    0.000 /usr/local/lib/python3.8/dist-packages/keras/engine/input_spec.py:155(assert_input_compatibility)
# 2132/2082    0.005    0.000    0.016    0.000 {built-in method builtins.hasattr}
#       640    0.004    0.000    0.016    0.000 /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:2160(sum)
#        10    0.000    0.000    0.016    0.002 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:3078(zeros_like_v2)
#        10    0.000    0.000    0.016    0.002 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:2971(wrapped)
# 6482/6452    0.015    0.000    0.015    0.000 {built-in method builtins.len}
#        10    0.001    0.000    0.015    0.002 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:3124(zeros_like_impl)
#        10    0.001    0.000    0.014    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/data_structures.py:808(<dictcomp>)
#       980    0.010    0.000    0.014    0.000 {built-in method _abc._abc_instancecheck}
#      3270    0.014    0.000    0.014    0.000 {built-in method tensorflow.python.util._pywrap_utils.Flatten}
#       650    0.003    0.000    0.014    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:894(_check_index)
#        10    0.000    0.000    0.014    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_array_ops.py:12721(zeros_like)
#    230/50    0.001    0.000    0.013    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/_utils.py:59(wrap)
#        40    0.000    0.000    0.013    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py:10502(relu)
#        10    0.000    0.000    0.013    0.001 <decorator-gen-789>:1(cast)
#       830    0.005    0.000    0.013    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:6957(__exit__)
#        10    0.001    0.000    0.012    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:568(__init__)
#        10    0.000    0.000    0.012    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:150(_set_sample_static_shape_for_tensor)
#      1150    0.006    0.000    0.012    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/context.py:2161(executing_eagerly)
#       660    0.005    0.000    0.011    0.000 /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:69(_wrapreduction)
#       100    0.001    0.000    0.011    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/data_structures.py:907(_track_value)
#      1250    0.004    0.000    0.011    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:199(__init__)
#        30    0.000    0.000    0.011    0.000 {built-in method _functools.reduce}
#        50    0.005    0.000    0.011    0.000 /usr/local/lib/python3.8/dist-packages/numpy/core/shape_base.py:420(<listcomp>)
#        50    0.001    0.000    0.010    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py:3479(bias_add)
#       100    0.000    0.000    0.010    0.000 /usr/local/lib/python3.8/dist-packages/gym3/libenv.py:271(_maybe_copy_ndarray)
#       220    0.006    0.000    0.010    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:185(_sequence_like)
#       440    0.002    0.000    0.010    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:846(dims)
#        60    0.001    0.000    0.010    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:1231(is_compatible_with)
#        10    0.000    0.000    0.010    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:1214(<lambda>)
#        10    0.000    0.000    0.009    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/prefer_static.py:207(broadcast_shape)
#     90/80    0.001    0.000    0.009    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/ops.py:139(_convert_to_tensor)
#        60    0.001    0.000    0.009    0.000 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:2449(_maybe_cast_inputs)
#        30    0.001    0.000    0.009    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/base.py:927(_track_trackable)
#        20    0.000    0.000    0.009    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:545(broadcast_static_shape)
#        20    0.000    0.000    0.009    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/common_shapes.py:85(broadcast_shape)
#        70    0.000    0.000    0.009    0.000 /usr/lib/python3.8/contextlib.py:415(enter_context)
#      3944    0.008    0.000    0.008    0.000 /tmp/ipykernel_32976/3934244552.py:31(get_state)
#       830    0.008    0.000    0.008    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/context.py:985(scope_name)
#       440    0.002    0.000    0.008    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:858(<listcomp>)
#      4880    0.008    0.000    0.008    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/context.py:2131(context_safe)
#       100    0.001    0.000    0.008    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/data_structures.py:204(_track_value)
#        20    0.000    0.000    0.008    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/tf_inspect.py:247(getfullargspec)
#        20    0.000    0.000    0.008    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/numpy_array.py:152(_concat)
#        20    0.007    0.000    0.007    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/common_shapes.py:21(_broadcast_shape_helper)
#        20    0.002    0.000    0.007    0.000 /usr/lib/python3.8/inspect.py:1102(getfullargspec)
#        10    0.001    0.000    0.007    0.001 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:979(<listcomp>)
#        10    0.000    0.000    0.007    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:1092(batch_shape)
#        20    0.000    0.000    0.007    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_array_ops.py:8561(reshape_eager_fallback)
#        50    0.000    0.000    0.007    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py:646(bias_add)
#        10    0.000    0.000    0.007    0.001 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:820(get_outer_rank)
#      3970    0.007    0.000    0.007    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:1575(<genexpr>)
#        20    0.000    0.000    0.007    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/numpy_array.py:125(_args_to_matching_arrays)
#        20    0.001    0.000    0.007    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/math_ops.py:3488(matmul)
#        10    0.000    0.000    0.007    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:1061(_batch_shape)
#        10    0.000    0.000    0.006    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/batch_shape_lib.py:40(inferred_batch_shape)
#        10    0.000    0.000    0.006    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:2012(_expand_sample_shape_to_vector)
#   520/480    0.004    0.000    0.006    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/data_structures.py:817(__getattribute__)
#       530    0.002    0.000    0.006    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:255(_yield_value)
#        70    0.003    0.000    0.006    0.000 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:3380(_in_functional_construction_mode)
#       830    0.003    0.000    0.006    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:6947(_restore_name_scope)
#       270    0.002    0.000    0.006    0.000 {built-in method builtins.any}
#        10    0.000    0.000    0.006    0.001 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:2483(_cast_single_input)
#        20    0.000    0.000    0.005    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/math_ops.py:1398(binary_op_wrapper)
#        50    0.001    0.000    0.005    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py:227(args_to_matching_eager)
#      3200    0.005    0.000    0.005    0.000 {built-in method numpy.asanyarray}
#        50    0.000    0.000    0.005    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/ops.py:213(_default_convert_to_tensor)
#        10    0.000    0.000    0.005    0.001 <decorator-gen-841>:1(minimum)
#        10    0.000    0.000    0.005    0.001 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/tf_inspect.py:108(getargspec)
#      3090    0.005    0.000    0.005    0.000 {method '_datatype_enum' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#        90    0.001    0.000    0.005    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/base.py:583(_method_wrapper)
#       840    0.003    0.000    0.005    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:6905(__init__)
#      1660    0.005    0.000    0.005    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/context.py:990(scope_name)
#     40/20    0.000    0.000    0.005    0.000 /usr/lib/python3.8/inspect.py:2218(_signature_from_callable)
#        40    0.001    0.000    0.005    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:1005(concatenate)
#        10    0.000    0.000    0.005    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/tf_inspect.py:65(_getargspec)
#      2090    0.005    0.000    0.005    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/context.py:995(device_name)
#        10    0.000    0.000    0.004    0.000 <decorator-gen-863>:1(reduce_prod)
#        30    0.000    0.000    0.004    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/tensorshape_util.py:285(set_shape)
#       670    0.002    0.000    0.004    0.000 /usr/lib/python3.8/abc.py:100(__subclasscheck__)
#        20    0.001    0.000    0.004    0.000 /usr/lib/python3.8/inspect.py:2124(_signature_from_function)
#       530    0.002    0.000    0.004    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:260(_yield_sorted_items)
#        30    0.000    0.000    0.004    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1301(set_shape)
#        10    0.000    0.000    0.004    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/tf_inspect.py:269(getcallargs)
#       150    0.001    0.000    0.004    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_util.py:808(constant_value)
#        20    0.000    0.000    0.004    0.000 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:2162(_clear_losses)
#      2240    0.004    0.000    0.004    0.000 {method 'get' of 'dict' objects}
#      2090    0.004    0.000    0.004    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/context.py:931(_handle)
#        10    0.000    0.000    0.004    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/categorical.py:331(_logits_parameter_no_checks)
#       660    0.004    0.000    0.004    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        30    0.000    0.000    0.004    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/base.py:982(_handle_deferred_dependencies)
#      2090    0.004    0.000    0.004    0.000 {built-in method builtins.issubclass}
#      2090    0.004    0.000    0.004    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/context.py:580(ensure_initialized)
#        10    0.000    0.000    0.003    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/tensor_util.py:123(identity_as_tensor)
#        70    0.000    0.000    0.003    0.000 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:2943(_flatten_layers)
#        10    0.000    0.000    0.003    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/math_ops.py:1728(_add_dispatch)
#        20    0.000    0.000    0.003    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_math_ops.py:5986(mat_mul)
#        10    0.000    0.000    0.003    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:869(<listcomp>)
#       610    0.002    0.000    0.003    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:839(rank)
#        50    0.000    0.000    0.003    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/prefer_static.py:76(<listcomp>)
#        70    0.001    0.000    0.003    0.000 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:2949(_flatten_modules)
#       100    0.003    0.000    0.003    0.000 {built-in method numpy.array}
#        10    0.000    0.000    0.003    0.000 /usr/local/lib/python3.8/dist-packages/keras/layers/reshaping/flatten.py:67(call)
#        10    0.000    0.000    0.003    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/ops.py:385(<lambda>)
#     70/50    0.001    0.000    0.003    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/ops.py:248(_default_convert_to_tensor_with_dtype)
#        10    0.003    0.000    0.003    0.000 {method 'clear' of 'list' objects}
#        20    0.000    0.000    0.003    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:1981(_name_and_control_scope)
#        20    0.000    0.000    0.003    0.000 /usr/local/lib/python3.8/dist-packages/cffi/api.py:242(new)
#        10    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/ops.py:375(_cast)
#        10    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:2208(transpose_v2)
#        30    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py:29(quick_execute)
#        70    0.001    0.000    0.002    0.000 /usr/lib/python3.8/contextlib.py:482(__exit__)
#       940    0.002    0.000    0.002    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsNested}
#        10    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/ops.py:538(_convert_tensorshape_to_tensor)
#     60/50    0.001    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/ops.py:167(_infer_dtype)
#        10    0.001    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:2289(transpose)
#        10    0.000    0.000    0.002    0.000 <decorator-gen-773>:1(shape_v2)
#        20    0.002    0.000    0.002    0.000 {built-in method _cffi_backend.newp}
#        10    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:251(identity)
#        10    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/prefer_static.py:94(wrap)
#     22/12    0.000    0.000    0.002    0.000 /usr/lib/python3.8/contextlib.py:108(__enter__)
#        10    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/prefer_static.py:396(_shape)
#        10    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py:3829(softmax_v2)
#        50    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:888(__getitem__)
#        70    0.001    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:2477(_should_cast_single_input)
#        10    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py:3743(_wrap_2d_function)
#        30    0.001    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/environments/py_environment.py:104(should_reset)
#       160    0.001    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_util.py:1030(is_tf_type)
#        10    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/tensorshape_util.py:112(concatenate)
#        30    0.002    0.000    0.002    0.000 {built-in method tensorflow.python._pywrap_tfe.TFE_Py_Execute}
#       210    0.001    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/dtypes.py:678(as_dtype)
#        10    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/distribution_util.py:1371(expand_to_vector)
#       170    0.001    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:147(is_namedtuple)
#        10    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/batch_shape_lib.py:142(get_batch_shape_part)
#        10    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/module/module.py:108(__init__)
#       670    0.002    0.000    0.002    0.000 {built-in method _abc._abc_subclasscheck}
#       280    0.001    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:912(<genexpr>)
#       240    0.001    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/dtypes.py:63(base_dtype)
#       100    0.001    0.000    0.002    0.000 /usr/lib/python3.8/inspect.py:2489(__init__)
#        10    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/categorical.py:346(_num_categories)
#        20    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/categorical.py:371(_parameter_control_dependencies)
#        20    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:688(parameter_properties)
#        90    0.001    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/base.py:708(_maybe_initialize_trackable)
#        20    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/distributions/masked.py:107(parameters)
#        70    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/tensorshape_util.py:265(rank)
#       830    0.002    0.000    0.002    0.000 {method 'pop' of 'list' objects}
#       120    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/ops.py:479(<lambda>)
#        20    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/resource_variable_ops.py:558(_shape_tuple)
#       980    0.002    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:265(value)
#        10    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/numpy_math.py:736(<lambda>)
#        20    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:383(<listcomp>)
#       650    0.002    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:6706(<genexpr>)
#        20    0.000    0.000    0.002    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/categorical.py:391(maybe_assert_categorical_param_correctness)
#       180    0.001    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/dtypes.py:188(__ne__)
#       860    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#        50    0.001    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/numpy/core/shape_base.py:432(<listcomp>)
#        20    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/resource_variable_ops.py:553(_shape_as_list)
#        80    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:1518(<genexpr>)
#        20    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/name_util.py:57(instance_scope)
#        20    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:814(parameters)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:1159(event_shape)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/_utils.py:127(<lambda>)
#        20    0.000    0.000    0.001    0.000 /usr/lib/python3.8/multiprocessing/pool.py:791(__init__)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/specs/array_spec.py:83(sample_spec_nest)
#       660    0.001    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:70(<dictcomp>)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/data_structures.py:900(_update_snapshot)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/batch_shape_lib.py:188(_truncate_shape)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/numpy_math.py:813(_apply_reduction)
#       120    0.001    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:138(_sorted)
#        90    0.001    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:271(is_compatible_with)
#        30    0.001    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:66(assert_same_structure)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/dtype_util.py:86(common_dtype)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/prefer_static.py:186(rank_from_shape)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:581(shape_v2)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:857(<listcomp>)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py:352(_tensor_shape_tensor_conversion_function)
#        50    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:1159(flatten_up_to)
#       170    0.001    0.000    0.001    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsNamedtuple}
#        70    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:2611(_get_input_masks)
#        20    0.000    0.000    0.001    0.000 /usr/lib/python3.8/multiprocessing/pool.py:744(__init__)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:846(<listcomp>)
#       100    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:1425(as_shape)
#       210    0.001    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:3384(<genexpr>)
#        70    0.001    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/tf_decorator.py:229(__init__)
#       640    0.001    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:2155(_sum_dispatcher)
#       220    0.001    0.000    0.001    0.000 {method '_shape_tuple' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#        70    0.000    0.000    0.001    0.000 /usr/lib/python3.8/contextlib.py:458(_push_cm_exit)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:633(shape)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/math_ops.py:1759(_mul_dispatch)
#        20    0.001    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/trajectories/time_step.py:87(is_last)
#        90    0.001    0.000    0.001    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       110    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:860(ndims)
#        20    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:2573(_set_mask_metadata)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:660(shape_internal)
#        30    0.001    0.000    0.001    0.000 {method 'format' of 'str' objects}
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/math_ops.py:2248(reduce_sum)
#        30    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/nest.py:180(flatten)
#        60    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_util.py:1086(maybe_set_static_shape)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:207(fill)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/name_util.py:72(_instance_scope_name)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1269(get_shape)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/math_ops.py:2315(reduce_sum_with_dims)
#        20    0.000    0.000    0.001    0.000 /usr/lib/python3.8/inspect.py:2772(__init__)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/numpy_array.py:148(<listcomp>)
#        10    0.000    0.000    0.001    0.000 {method 'extendleft' of 'collections.deque' objects}
#       240    0.001    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/dtypes.py:50(_is_ref_dtype)
#        30    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/environments/wrappers.py:53(__getattr__)
#        30    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tree/__init__.py:195(flatten)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py:10909(softmax)
#        50    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:475(assert_same_structure)
#        50    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:1323(is_fully_defined)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/name_util.py:38(strip_invalid_chars)
#        20    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/tensorshape_util.py:214(is_fully_defined)
#        20    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/tensor_util.py:34(convert_nonref_to_tensor)
#       140    0.001    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:951(<genexpr>)
#        10    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(prod)
#        70    0.000    0.000    0.001    0.000 /usr/lib/python3.8/inspect.py:1520(currentframe)
#        10    0.000    0.000    0.001    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/data_structures.py:473(__init__)
#       420    0.001    0.000    0.001    0.000 {method 'pop' of 'dict' objects}
#     22/12    0.000    0.000    0.001    0.000 /usr/lib/python3.8/contextlib.py:117(__exit__)
# ...
#       100    0.000    0.000    0.000    0.000 /usr/lib/python3.8/inspect.py:2551(kind)
#        20    0.000    0.000    0.000    0.000 /usr/lib/python3.8/multiprocessing/pool.py:753(ready)
#        70    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#        20    0.000    0.000    0.000    0.000 /usr/lib/python3.8/threading.py:249(__exit__)
#        20    0.000    0.000    0.000    0.000 /usr/lib/python3.8/threading.py:246(__enter__)
#        60    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/data_structures.py:66(__init__)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:864(<listcomp>)
#        20    0.000    0.000    0.000    0.000 /usr/lib/python3.8/threading.py:261(_is_owned)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/tensorshape_util.py:63(_cast_tensorshape)
#        70    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#        10    0.000    0.000    0.000    0.000 /usr/lib/python3.8/re.py:289(_compile)
#        20    0.000    0.000    0.000    0.000 /usr/lib/python3.8/_weakrefset.py:36(__init__)
#        30    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:390(<genexpr>)
#        70    0.000    0.000    0.000    0.000 /usr/lib/python3.8/contextlib.py:479(__enter__)
#        30    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/base.py:791(_deferred_dependencies)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/categorical.py:231(_event_shape)
#        70    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.deque' objects}
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/backend/numpy/numpy_math.py:164(_astuple)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/tf2.py:35(enabled)
#        70    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/config.py:1092(is_op_determinism_enabled)
#        10    0.000    0.000    0.000    0.000 /usr/lib/python3.8/_weakrefset.py:26(__exit__)
#        10    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py:157(make_int)
#        70    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/numpy/core/multiarray.py:148(concatenate)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:849(<genexpr>)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/parameter_properties.py:312(instance_event_ndims)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:865(__len__)
#        20    0.000    0.000    0.000    0.000 /usr/lib/python3.8/threading.py:255(_release_save)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/cffi/api.py:180(_typeof)
#        50    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:384(<listcomp>)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/math_ops.py:2160(_may_reduce_to_scalar)
#        10    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:853(<genexpr>)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/data_structures.py:192(_attribute_sentinel)
#        10    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#        10    0.000    0.000    0.000    0.000 /usr/lib/python3.8/copy.py:66(copy)
#        60    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#        40    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        30    0.000    0.000    0.000    0.000 {built-in method tensorflow.python._pywrap_tfe.TFE_Py_TapeSetIsEmpty}
#        30    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/policies/py_policy.py:174(action_spec)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3214(_update_code_co_name)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:386(<listcomp>)
#        30    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 /usr/lib/python3.8/_weakrefset.py:20(__enter__)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/math_ops.py:1343(maybe_promote_tensors)
#        30    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:314(is_nested)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/tensor_util.py:155(is_variable)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:910(_is_undefined_dimension)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:871(compute_mask)
#        30    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/base.py:70(__init__)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:147(<dictcomp>)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/auto_composite_tensor.py:41(is_deferred_assertion_context)
#        10    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_determinism.is_enabled}
#        10    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.platform._pywrap_tf2.is_enabled}
#        40    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:2622(<genexpr>)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/tensor_util.py:165(is_module)
#        30    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_spec.py:56(dtype)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/math_ops.py:2155(_has_fully_defined_shape)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_spec.py:51(shape)
#        20    0.000    0.000    0.000    0.000 /usr/lib/python3.8/multiprocessing/pool.py:348(_check_running)
#        30    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/networks/network.py:183(input_tensor_spec)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:101(dimension_value)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:7265(__init__)
#        20    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/resource_variable_ops.py:525(dtype)
#        10    0.000    0.000    0.000    0.000 /usr/lib/python3.8/inspect.py:80(ismethod)
#        20    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        30    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/platform/device_context.py:17(enclosing_tpu_context)
#        20    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:804(name)
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/numpy/core/getlimits.py:671(max)
#        10    0.000    0.000    0.000    0.000 <string>:1(__new__)
#        20    0.000    0.000    0.000    0.000 /usr/lib/python3.8/_collections_abc.py:302(__subclasshook__)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/numpy/core/getlimits.py:658(min)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/context.py:2151(global_seed)
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#        10    0.000    0.000    0.000    0.000 /tf/mlrl/meta/meta_env.py:74(mask_token_splitter)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/policies/py_policy.py:163(time_step_spec)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/distributions/masked.py:103(mask)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/environments/py_environment.py:176(current_time_step)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/nest_utils.py:880(<genexpr>)
#        20    0.000    0.000    0.000    0.000 /usr/lib/python3.8/threading.py:513(is_set)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_shape.py:810(_v2_behavior)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:915(validate_args)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/categorical.py:218(logits)
#        20    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 /usr/lib/python3.8/_weakrefset.py:16(__init__)
#        20    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#        20    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/networks/utils.py:52(__init__)
#        20    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#        20    0.000    0.000    0.000    0.000 /usr/lib/python3.8/inspect.py:2857(parameters)
#        20    0.000    0.000    0.000    0.000 /usr/lib/python3.8/inspect.py:2861(return_annotation)
#        20    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/tf_inspect.py:292(<listcomp>)
#         4    0.000    0.000    0.000    0.000 /usr/lib/python3.8/dis.py:449(findlinestarts)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer_utils.py:512(training)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/traitlets/traitlets.py:692(__get__)
#        10    0.000    0.000    0.000    0.000 /usr/lib/python3.8/_weakrefset.py:52(_commit_removals)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/specs/array_spec.py:355(minimum)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        10    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/specs/array_spec.py:179(dtype)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/internal/name_util.py:47(get_name_scope_name)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/policies/py_policy.py:123(observation_and_action_constraint_splitter)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/networks/network.py:179(state_spec)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/numpy/core/multiarray.py:1071(copyto)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:635(<genexpr>)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/math_ops.py:2137(_ReductionDims)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:2644(_get_call_arg_value)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tf_agents/utils/common.py:1428(safe_has_state)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/data_structures.py:70(_should_wrap_tuple)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/data_structures.py:534(_make_storage)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/keras/activations.py:459(linear)
#        10    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/tf_inspect.py:132(<genexpr>)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:2965(_prod_dispatcher)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/data_structures.py:392(_values)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:2399(_all_dispatcher)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/traitlets/traitlets.py:654(get)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_32976/1631964753.py:14(<cell line: 14>)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/IPython/core/compilerop.py:174(extra_flags)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:1191(user_global_ns)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3312(compare)
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'code' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
# video_env = create_batched_procgen_meta_envs(n_envs=64, object_config=object_config, env_multithreading=False, **args)
from mlrl.experiments.procgen_meta import create_procgen_meta_env

n_envs = 2

meta_envs = [
    create_procgen_meta_env(
        object_config,
        min_computation_steps=5,
        **args
    )
    for _ in range(n_envs)
]

video_env = BatchedProcgenMetaEnv(meta_envs, len(ProcgenState.ACTIONS), object_config, multithreading=True)


policy = create_random_search_policy_no_terminate(video_env)


from mlrl.runners.eval_runner import EvalRunner


runner = EvalRunner(100, video_env, policy, video_env=video_env)

# %%
from mlrl.utils.render_utils import embed_mp4

embed_mp4(runner.create_policy_eval_video(60))
# Out:
#     <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#     Your browser does not support the video tag.
#     </video>
